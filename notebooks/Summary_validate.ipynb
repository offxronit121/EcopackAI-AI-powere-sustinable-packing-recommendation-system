# %%
import pandas as pd
import matplotlib.pyplot as plt
materials = pd.read_csv('/content/materials_featured.csv')

# %%
materials.columns
# Out:
# Index(['material_id', 'material_type', 'strength_mpa', 'weight_capacity',
#        'co2_emission_per_kg', 'biodegradability_score', 'recyclability_pct',
#        'cost_inr_per_kg', 'material_category', 'strength_level', 'co2_norm',
#        'cost_norm', 'strength_norm', 'emission_score', 'recyclability_index',
#        'co2_impact_index', 'cost_score', 'cost_efficiency_index',
#        'material_suitability_score'],
#       dtype='object')

# %%
materials.shape
# Out:
# (22, 19)

# %%
materials[
    [
        "emission_score",
        "recyclability_index",
        "co2_impact_index",
        "cost_efficiency_index",
        "material_suitability_score"
    ]
].isnull().sum()
# Out:
# emission_score                0
# recyclability_index           0
# co2_impact_index              0
# cost_efficiency_index         0
# material_suitability_score    0
# dtype: int64

# %%
materials[
    [
        "emission_score",
        "recyclability_index",
        "co2_impact_index",
        "cost_efficiency_index",
        "material_suitability_score"
    ]
].describe()
# Out:
#        emission_score  recyclability_index  co2_impact_index  \
# count       22.000000            22.000000         22.000000
# mean         0.848485             0.726364          0.742152
# std          0.202673             0.169468          0.171221
# min          0.000000             0.300000          0.285000
# 25%          0.844298             0.612500          0.642303
# 50%          0.877193             0.700000          0.785526
# 75%          0.945175             0.850000          0.883575
# max          1.000000             1.000000          0.933070
#
#        cost_efficiency_index  material_suitability_score
# count              22.000000                   22.000000
# mean                0.515205                    0.606465
# std                 0.224215                    0.148198
# min                 0.031263                    0.355521
# 25%                 0.435621                    0.518535
# 50%                 0.499000                    0.568870
# 75%                 0.567603                    0.698485
# max                 0.972864                    0.920003

# %%
materials[[
    "co2_emission_per_kg",
    "emission_score",
    "cost_inr_per_kg",
    "cost_efficiency_index",
    "strength_mpa",
    "strength_norm"
]].corr()
# Out:
#                        co2_emission_per_kg  emission_score  cost_inr_per_kg  \
# co2_emission_per_kg               1.000000       -1.000000         0.342858
# emission_score                   -1.000000        1.000000        -0.342858
# cost_inr_per_kg                   0.342858       -0.342858         1.000000
# cost_efficiency_index            -0.339417        0.339417        -0.863465
# strength_mpa                     -0.179494        0.179494        -0.282986
# strength_norm                    -0.179494        0.179494        -0.282986
#
#                        cost_efficiency_index  strength_mpa  strength_norm
# co2_emission_per_kg                -0.339417     -0.179494      -0.179494
# emission_score                      0.339417      0.179494       0.179494
# cost_inr_per_kg                    -0.863465     -0.282986      -0.282986
# cost_efficiency_index               1.000000      0.728139       0.728139
# strength_mpa                        0.728139      1.000000       1.000000
# strength_norm                       0.728139      1.000000       1.000000

# %%
materials.sort_values(
    "material_suitability_score",
    ascending=False
)[
    [
        "material_type",
        "material_category",
        "material_suitability_score",
        "co2_impact_index",
        "cost_efficiency_index"
    ]
].head(5)
# Out:
#                material_type material_category  material_suitability_score  \
# 20              Bamboo Fiber     Natural Fiber                    0.920003
# 19                Jute Fiber     Natural Fiber                    0.849071
# 21              Cotton Fiber     Natural Fiber                    0.848294
# 14      Steel (Carbon Steel)             Metal                    0.725262
# 10  Kraft Paper (Unbleached)             Paper                    0.703568
#
#     co2_impact_index  cost_efficiency_index
# 20          0.910000               0.972864
# 19          0.875614               0.900242
# 21          0.886228               0.870091
# 14          0.715053               0.730252
# 10          0.933070               0.564812

# %%
materials.sort_values(
    "material_suitability_score"
)[
    [
        "material_type",
        "material_category",
        "material_suitability_score"
    ]
].head(5)
# Out:
#                  material_type material_category  material_suitability_score
# 13          Aluminum (Primary)             Metal                    0.355521
# 7   Expanded Polystyrene (EPS)           Plastic                    0.386002
# 16              PHA Bioplastic        Biopolymer                    0.456902
# 6             Polystyrene (PS)           Plastic                    0.480414
# 5                  PVC Plastic           Plastic                    0.495447

# %%
materials.columns
# Out:
# Index(['material_id', 'material_type', 'strength_mpa', 'weight_capacity',
#        'co2_emission_per_kg', 'biodegradability_score', 'recyclability_pct',
#        'cost_inr_per_kg', 'material_category', 'strength_level', 'co2_norm',
#        'cost_norm', 'strength_norm', 'emission_score', 'recyclability_index',
#        'co2_impact_index', 'cost_score', 'cost_efficiency_index',
#        'material_suitability_score'],
#       dtype='object')
